# %%
from morse import detect_frequency, spectrogram, parse, decode
from scipy.io.wavfile import read

# %%
rate, data = read("C:/Users/danie/Videos/help34.wav")
if data.ndim >= 2:
    data = data.mean(axis = 1) # Convert stereo to mono

# %%
F = detect_frequency(data, rate)
print(f"Detected frequency: {F} Hz")
# Out:
# Detected frequency: 1005.7431313847482 Hz

# %%
spec = spectrogram(data, rate, F)
signal = spec > spec.mean() / 2
morse, wpm = parse(signal, rate, False)
print(morse)
# Out:
#  -.. ..- .-.. . . -.. . -.-. --- .-. ..- -- . ... .--. .- .-. .. .- --- .-. ..

# %%
"-.. ..- .-.. . . -.. . -.-. --- .-. ..- -- . ... .--. .- .-. .. .- --- .-. .."
# Out:
# '-.. ..- .-.. . . -.. . -.-. --- .-. ..- -- . ... .--. .- .-. .. .- --- .-. ..'

# %%
message = decode(morse)
print(message)
# Out:
# DULEEDECORUMESPARIAORI

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(spec[:1000])
